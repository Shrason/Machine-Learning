# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrason/Machine-Learning/blob/main/RandomTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Dataset = pd.read_csv('Salary_data.csv')

# %%
X = Dataset.iloc[:,1:-1].values
y = Dataset.iloc[:,-1].values

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=12,random_state=42)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=12, random_state=42)

# %%
regressor.predict([[5.5]])
# Out:
# array([119166.66666667])

# %%
X_grid = np.arange(min(X),max(X),0.01)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y,color = 'red')
plt.plot (X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Random Tree Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\shrad\AppData\Local\Temp\ipykernel_6128\2924514573.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X),max(X),0.01)
